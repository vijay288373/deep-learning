# %% [markdown]
# <a href="https://colab.research.google.com/github/vijay288373/deep-learning/blob/main/lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1st experiment
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Simple example data for binary classification
y_true_binary = np.array([0, 1, 0, 1, 0, 1, 1, 0])
y_pred_binary = np.array([0, 1, 1, 1, 0, 0, 1, 0])

# Bi-level (binary) confusion matrix
cm_binary = confusion_matrix(y_true_binary, y_pred_binary)
print("Bi-level Confusion Matrix:")
print(cm_binary)

# Classification report for binary case
report_binary = classification_report(y_true_binary, y_pred_binary)
print("\nBi-level Classification Report:")
print(report_binary)

# Simple example data for multi-class classification
y_true_multi = np.array([0, 1, 2, 0, 1, 2, 1, 0, 2, 1])
y_pred_multi = np.array([0, 1, 1, 0, 2, 2, 1, 0, 2, 0])

# Multi-level (multi-class) confusion matrix
cm_multi = confusion_matrix(y_true_multi, y_pred_multi)
print("\nMulti-level Confusion Matrix:")
print(cm_multi)

# Classification report for multi-class case
report_multi = classification_report(y_true_multi, y_pred_multi)
print("\nMulti-level Classification Report:")
print(report_multi)
# Out:
# Bi-level Confusion Matrix:
# [[3 1]
#  [1 3]]
#
# Bi-level Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.75         8
#    macro avg       0.75      0.75      0.75         8
# weighted avg       0.75      0.75      0.75         8
#
#
# Multi-level Confusion Matrix:
# [[3 0 0]
#  [1 2 1]
#  [0 1 2]]
#
# Multi-level Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       0.67      0.50      0.57         4
#            2       0.67      0.67      0.67         3
#
#     accuracy                           0.70        10
#    macro avg       0.69      0.72      0.70        10
# weighted avg       0.69      0.70      0.69        10

# %%
#2nd experiment
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# 1. Load Data: Generate a simple non-linear dataset
X, y = make_regression(n_samples=100, n_features=1, noise=10, random_state=42)
y = y**2 # Introduce non-linearity

# Reshape X to be a 2D array for scikit-learn
X = X.reshape(-1, 1)

# 2. Split Data: Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Train Model: Train a complex model (high degree polynomial regression)
# This is likely to overfit a simple non-linear dataset
model = make_pipeline(PolynomialFeatures(degree=10), LinearRegression())
model.fit(X_train, y_train)

# 4. Evaluate Model: Predict and evaluate on both training and testing sets
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

print(f"Training Mean Squared Error: {train_mse:.2f}")
print(f"Testing Mean Squared Error: {test_mse:.2f}")

# Optional: Visualize results to show overfitting
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Testing data')
X_plot = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
y_plot = model.predict(X_plot)
plt.plot(X_plot, y_plot, color='red', label='Model prediction')
plt.title('Overfitting Demonstration')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Training Mean Squared Error: 203715.23
# Testing Mean Squared Error: 890223.94

# %%
#3rd experiment
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

# 1. Load Data: Generate a simple linear dataset
X, y = make_regression(n_samples=100, n_features=1, noise=10, random_state=42)

# Reshape X to be a 2D array for scikit-learn
X = X.reshape(-1, 1)

# 2. Split Data: Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Train Model: Train a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# 4. Make Predictions: Predict on the testing set
y_pred = model.predict(X_test)

# 5. Evaluate Model: Evaluate performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared: {r2:.2f}")

# Optional: Visualize results
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual data')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Regression line')
plt.title('Linear Regression Performance')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 103.47
# R-squared: 0.94

# %%
#4th experiment
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 1. Load Data: Generate a simple classification dataset
X, y = make_classification(n_samples=100, n_features=2, n_informative=2, n_redundant=0, random_state=42)

# 2. Split Data: Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Train Model: Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# 4. Make Predictions: Predict on the testing set
y_pred = model.predict(X_test)

# 5. Evaluate Model: Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
print("\nConfusion Matrix:")
print(cm)
# Out:
# Accuracy: 0.97
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        16
#            1       0.93      1.00      0.97        14
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
#
#
# Confusion Matrix:
# [[15  1]
#  [ 0 14]]

# %%
#5th experiment
import numpy as np
import matplotlib.pyplot as plt

# 1. Define Objective Function and Gradient
def objective_function(x):
    return x**2

def gradient(x):
    return 2 * x

# 2. Implement Gradient Descent
def gradient_descent(objective_func, gradient_func, start_x, learning_rate, n_iterations):
    x = start_x
    x_history = [x]
    for _ in range(n_iterations):
        grad = gradient_func(x)
        x = x - learning_rate * grad
        x_history.append(x)
    return x, x_history

# 3. Run Gradient Descent
start_point = 10
learning_rate = 0.1
n_iterations = 50
optimal_x, x_history = gradient_descent(objective_function, gradient, start_point, learning_rate, n_iterations)

print(f"Optimal x found: {optimal_x:.4f}")

# 4. Visualize Results
x_values = np.linspace(-11, 11, 100)
y_values = objective_function(x_values)

plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Objective Function')
plt.plot(x_history, [objective_function(x) for x in x_history], 'o-', color='red', label='Gradient Descent Path')
plt.title('Gradient Descent Demonstration')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Optimal x found: 0.0001

# %%
#6th experiment
# Install OpenCV
# !pip install opencv-python matplotlib numpy

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Create a simple dummy image for demonstration (replace with your image loading if needed)
# A grayscale image with two distinct intensity regions
img = np.zeros((200, 200), dtype=np.uint8)
img[50:150, 50:150] = 150
img = img + np.random.randint(-20, 20, size=(200, 200), dtype=np.int16)
img = np.clip(img, 0, 255).astype(np.uint8)


# 1. Load Image (using the dummy image created above)
# If you have an image file, you can load it like this:
# img = cv2.imread('your_image.jpg', 0) # Load as grayscale

# Check if image was loaded
if img is None:
    print("Error: Could not load image.")
else:
    # 2. Apply Otsu's Thresholding
    # 0 is the initial threshold value, 255 is the maximum value
    # cv2.THRESH_BINARY creates a binary image (0 or 255)
    # cv2.THRESH_OTSU applies Otsu's method
    ret, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    print(f"Otsu's threshold value: {ret}")

    # 3. Visualize Results
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(thresh, cmap='gray')
    plt.title('Otsu\'s Thresholding')
    plt.axis('off')

    plt.show()
# Out:
# ...
# Otsu's threshold value: 19.0

# %%
#7th experiment
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create a simple dummy image for demonstration (two overlapping circles)
img = np.zeros((200, 200, 3), dtype=np.uint8)
cv2.circle(img, (80, 100), 50, (255, 0, 0), -1)
cv2.circle(img, (120, 100), 50, (0, 0, 255), -1)

# 1. Load Image (using the dummy image created above)
# If you have an image file, you can load it like this:
# img = cv2.imread('your_image.jpg')

# Check if image was loaded
if img is None:
    print("Error: Could not load image.")
else:
    # 2. Pre-processing
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Noise removal
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=2)

    # Sure background area
    sure_bg = cv2.dilate(opening, kernel, iterations=3)

    # Sure foreground area
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    ret, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)

    # Unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)

    # 3. Find Markers
    ret, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0

    # 4. Apply Watershed Algorithm
    markers = cv2.watershed(img, markers)
    img[markers == -1] = [255, 0, 0] # Mark the boundaries in red

    # 5. Visualize Results
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Watershed Segmentation')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(thresh, cmap='gray')
    plt.title('Thresholded Image')
    plt.axis('off')

    plt.show()
